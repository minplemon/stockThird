# %%
from jqdatasdk import *
auth('18620668927', 'minpeng123')

# %%
#获取申万一级行业日行情数据
#记录了申万一级行业指数的历史日行情数据，每日18:00更新
# 查询最近10个交易日申万一级行业指数-农林牧渔行业（801010）的日行情数据。
finance.run_query(query(finance.SW1_DAILY_PRICE).filter(finance.SW1_DAILY_PRICE.code=='801010').order_by(finance.SW1_DAILY_PRICE.date.desc()).limit(10))
# Out:
#         id        date    code  name     open     high      low    close  \
# 0  1775366  2019-07-09  801010  农林牧渔  3354.90  3419.91  3304.41  3388.38
# 1  1776166  2019-07-08  801010  农林牧渔  3380.26  3405.14  3316.67  3367.09
# 2  1775899  2019-07-05  801010  农林牧渔  3262.32  3363.94  3262.30  3353.16
# 3  1774834  2019-07-04  801010  农林牧渔  3308.49  3314.15  3243.09  3250.67
# 4  1774302  2019-07-03  801010  农林牧渔  3338.17  3353.46  3287.85  3300.37
# 5  1773770  2019-07-02  801010  农林牧渔  3311.13  3389.59  3302.91  3351.21
# 6  1773504  2019-07-01  801010  农林牧渔  3260.81  3317.38  3235.03  3314.11
# 7  1772972  2019-06-28  801010  农林牧渔  3248.84  3253.88  3218.51  3228.72
# 8  1772440  2019-06-27  801010  农林牧渔  3239.86  3265.41  3218.27  3256.16
# 9  1771908  2019-06-26  801010  农林牧渔  3246.97  3266.85  3237.90  3238.67
#
#          volume         money  change_pct
# 0  1.766199e+09  2.377307e+10        0.63
# 1  2.032852e+09  2.590772e+10        0.42
# ...

# %%
#查询最近10个交易日申万一级行业指数-农林牧渔行业（801010）的估值数据
finance.run_query(query(finance.SW1_DAILY_VALUATION).filter(finance.SW1_DAILY_VALUATION.code=='801010').limit(10))
# Out:
#     id        date    code  name  turnover_ratio     pe    pb  average_price  \
# 0   19  1999-12-30  801010  农林牧渔            0.52  35.89  4.18          12.85
# 1   42  2000-01-04  801010  农林牧渔            0.74  38.40  4.59          13.22
# 2   65  2000-01-05  801010  农林牧渔            1.32  38.60  4.37          13.23
# 3   88  2000-01-06  801010  农林牧渔            1.57  39.99  4.52          13.69
# 4  111  2000-01-07  801010  农林牧渔            3.37  41.48  4.68          14.13
# 5  134  2000-01-10  801010  农林牧渔            2.82  42.18  4.77          14.43
# 6  157  2000-01-11  801010  农林牧渔            3.06  41.30  4.67          14.14
# 7  180  2000-01-12  801010  农林牧渔            2.23  40.39  4.57          13.86
# 8  203  2000-01-13  801010  农林牧渔            1.36  39.88  4.51          13.70
# 9  226  2000-01-14  801010  农林牧渔            1.09  39.64  4.49          13.66
#
#    money_ratio  circulating_market_cap  average_circulating_market_cap  \
# ...
