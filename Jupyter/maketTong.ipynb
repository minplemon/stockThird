# %%
from jqdatasdk import *
auth('18620668927', 'minpeng123')
# Out:
# auth success （JQData现有流量增加活动，详情请咨询JQData管理员，微信号：JQData02）

# %%
#记录同时在A股和H股上市的股票的价格比对
q = query(finance.STK_AH_PRICE_COMP).order_by(finance.STK_AH_PRICE_COMP.day).limit(90)
finance.run_query(q)
# Out:
#         id         day      name       a_code h_code  a_price  h_price  \
# 0     2994  2014-11-03  北京北辰实业股份  601588.XSHG  00588     3.88     2.35
# 1     8923  2014-11-03      东方电气  600875.XSHG  01072    14.90    12.92
# 2     9758  2014-11-03      中远海发  601866.XSHG  02866     3.37     2.25
# 3    10917  2014-11-03      上海电气  601727.XSHG  02727     5.97     3.77
# 4    11052  2014-11-03      中国人寿  601628.XSHG  02628    15.95    23.00
# 5    11680  2014-11-03      中远海能  600026.XSHG  01138     6.19     5.18
# 6    11870  2014-11-03      中信证券  600030.XSHG  06030    13.21    19.14
# 7    14772  2014-11-03  四川成渝高速公路  601107.XSHG  00107     3.72     2.94
# 8    20404  2014-11-03      中煤能源  601898.XSHG  01898     4.77     4.69
# 9    21128  2014-11-03   第一拖拉机股份  601038.XSHG  00038     9.38     4.96
# 10   21775  2014-11-03  江苏宁沪高速公路  600377.XSHG  00177     6.18     8.68
# 11   23818  2014-11-03      海螺水泥  600585.XSHG  00914    17.10    25.20
# ...
